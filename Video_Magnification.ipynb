# %%
#First of all change the runtime to GPU.
#And then mount your google drive so that you can access your own videos and photos.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
''' Since the preinstalled version of CUDA is 10.xx on google colab and the code was tested on CUDA 8.xx we need to change the CUDA version in order
to run the code'''
# !sudo apt-get purge --auto-remove cuda

# Downloading CUDA 8.0.61
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb

# Unpacking the .deb file for installation
# !dpkg -i cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb

# Doing an Update to ensure no anamolaties
# !apt-get update

# Install the newly downloaded CUDA
# !apt-get install cuda=8.0.61-1

# Since with CUDA 8.0.xx we need Libcudnn 6.xx we have to install it.
# !wget http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64/libcudnn6_6.0.21-1%2Bcuda8.0_amd64.deb
# !wget http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64/libcudnn6-dev_6.0.21-1%2Bcuda8.0_amd64.deb

# Installing CUDNN 6.0.xx
# !sudo dpkg -i libcudnn6_6.0.21-1+cuda8.0_amd64.deb
# !sudo dpkg -i libcudnn6-dev_6.0.21-1+cuda8.0_amd64.deb
# !sudo apt-get update
# !sudo apt-get install libcudnn6-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package 'cuda' is not installed, so not removed
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# --2024-04-05 15:26:25--  https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.199.39.144
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.nvidia.com/downloads/compute/cuda/8.0/prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb [following]
# --2024-04-05 15:26:26--  https://developer.nvidia.com/downloads/compute/cuda/8.0/prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Reusing existing connection to developer.nvidia.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?qS04VkCcBOksYr3QpHFRso2nMFwEQylZE58Obhsw23k7TyNlI5ArI7uqXcpeeiMmk-7pxIfNz4fV9710kI3jQkedROBNuhEck3bH6oIicf0pX2SNLK8juMhPs2qJqEaDqTBopivSlTMoaRW7U0FGr3txJ1V8k-XuUYo1FFti-3vPIG4lylUW-HJMxL7AHQa3HB1ZlY8zDzofhu9_LcwSZ2lNxQ== [following]
# --2024-04-05 15:26:27--  https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?qS04VkCcBOksYr3QpHFRso2nMFwEQylZE58Obhsw23k7TyNlI5ArI7uqXcpeeiMmk-7pxIfNz4fV9710kI3jQkedROBNuhEck3bH6oIicf0pX2SNLK8juMhPs2qJqEaDqTBopivSlTMoaRW7U0FGr3txJ1V8k-XuUYo1FFti-3vPIG4lylUW-HJMxL7AHQa3HB1ZlY8zDzofhu9_LcwSZ2lNxQ==
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1913589814 (1.8G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb’
#
# cuda-repo-ubuntu160 100%[===================>]   1.78G  38.4MB/s    in 20s
#
# 2024-04-05 15:26:47 (92.0 MB/s) - ‘cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb’ saved [1913589814/1913589814]
#
# Selecting previously unselected package cuda-repo-ubuntu1604-8-0-local-ga2.
# (Reading database ... 121753 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb ...
# Unpacking cuda-repo-ubuntu1604-8-0-local-ga2 (8.0.61-1) ...
# Setting up cuda-repo-ubuntu1604-8-0-local-ga2 (8.0.61-1) ...
# Warning: The postinst maintainerscript of the package cuda-repo-ubuntu1604-8-0-local-ga2
# Warning: seems to use apt-key (provided by apt) without depending on gpg, gnupg, or gnupg2.
# Warning: This will BREAK in the future and should be fixed by the package maintainer(s).
# Note: Check first if apt-key functionality is needed at all - it probably isn't!
# Warning: apt-key should not be used in scripts (called from postinst maintainerscript of the package cuda-repo-ubuntu1604-8-0-local-ga2)
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# OK
# Get:1 file:/var/cuda-repo-8-0-local-ga2  InRelease
# Ign:1 file:/var/cuda-repo-8-0-local-ga2  InRelease
# Get:2 file:/var/cuda-repo-8-0-local-ga2  Release [574 B]
# Get:2 file:/var/cuda-repo-8-0-local-ga2  Release [574 B]
# Get:3 file:/var/cuda-repo-8-0-local-ga2  Release.gpg [819 B]
# Get:3 file:/var/cuda-repo-8-0-local-ga2  Release.gpg [819 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:6 file:/var/cuda-repo-8-0-local-ga2  Packages [22.7 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [802 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:11 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:15 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,641 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [2,107 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,358 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,920 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,081 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [61.2 kB]
# Fetched 9,205 kB in 3s (3,076 kB/s)
# Reading package lists... Done
# W: file:/var/cuda-repo-8-0-local-ga2/Release.gpg: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-12 cuda-8-0 cuda-command-line-tools-8-0 cuda-core-8-0 cuda-cublas-8-0 cuda-cublas-dev-8-0
#   cuda-cudart-8-0 cuda-cudart-dev-8-0 cuda-cufft-8-0 cuda-cufft-dev-8-0 cuda-curand-8-0
#   cuda-curand-dev-8-0 cuda-cusolver-8-0 cuda-cusolver-dev-8-0 cuda-cusparse-8-0
#   cuda-cusparse-dev-8-0 cuda-demo-suite-8-0 cuda-documentation-8-0 cuda-driver-dev-8-0 cuda-drivers
#   cuda-drivers-550 cuda-license-8-0 cuda-misc-headers-8-0 cuda-npp-8-0 cuda-npp-dev-8-0
#   cuda-nvgraph-8-0 cuda-nvgraph-dev-8-0 cuda-nvml-dev-8-0 cuda-nvrtc-8-0 cuda-nvrtc-dev-8-0
#   cuda-runtime-8-0 cuda-samples-8-0 cuda-toolkit-8-0 cuda-visual-tools-8-0 dctrl-tools default-jre
#   default-jre-headless dkms fakeroot fonts-dejavu-core fonts-dejavu-extra freeglut3 freeglut3-dev
#   gcc-12 keyboard-configuration libasan8 libatk-wrapper-java libatk-wrapper-java-jni libegl-dev
#   libfakeroot libfontenc1 libgcc-12-dev libgl-dev libgl1-mesa-dev libgles-dev libgles1 libglu1-mesa
#   libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libice-dev libjansson4
#   liblocale-gettext-perl libnvidia-cfg1-550 libnvidia-common-550 libnvidia-compute-550
#   libnvidia-decode-550 libnvidia-encode-550 libnvidia-extra-550 libnvidia-fbc1-550 libnvidia-gl-550
#   libopengl-dev libsm-dev libtsan2 libudev1 libxcvt0 libxfixes-dev libxfont2 libxi-dev libxkbfile1
#   libxmu-dev libxmu-headers libxt-dev libxtst6 libxxf86dga1 nvidia-compute-utils-550
#   nvidia-dkms-550 nvidia-driver-550 nvidia-firmware-550-550.54.15 nvidia-kernel-common-550
#   nvidia-kernel-source-550 nvidia-prime nvidia-settings nvidia-utils-550 openjdk-11-jre
#   python3-xkit screen-resolution-extra systemd-hwe-hwdb udev x11-utils x11-xkb-utils xcvt
#   xfonts-base xfonts-encodings xfonts-utils xserver-common xserver-xorg-core
#   xserver-xorg-video-nvidia-550
# Suggested packages:
#   gcc-12-locales cpp-12-doc debtags menu gcc-12-multilib gcc-12-doc libice-doc libsm-doc libxt-doc
#   mesa-utils xfs | xserver xfonts-100dpi | xfonts-75dpi xfonts-scalable
# Recommended packages:
#   libnvidia-compute-550:i386 libnvidia-decode-550:i386 libnvidia-encode-550:i386
#   libnvidia-fbc1-550:i386 libnvidia-gl-550:i386
# The following NEW packages will be installed:
#   cpp-12 cuda cuda-8-0 cuda-command-line-tools-8-0 cuda-core-8-0 cuda-cublas-8-0
#   cuda-cublas-dev-8-0 cuda-cudart-8-0 cuda-cudart-dev-8-0 cuda-cufft-8-0 cuda-cufft-dev-8-0
#   cuda-curand-8-0 cuda-curand-dev-8-0 cuda-cusolver-8-0 cuda-cusolver-dev-8-0 cuda-cusparse-8-0
#   cuda-cusparse-dev-8-0 cuda-demo-suite-8-0 cuda-documentation-8-0 cuda-driver-dev-8-0 cuda-drivers
#   cuda-drivers-550 cuda-license-8-0 cuda-misc-headers-8-0 cuda-npp-8-0 cuda-npp-dev-8-0
#   cuda-nvgraph-8-0 cuda-nvgraph-dev-8-0 cuda-nvml-dev-8-0 cuda-nvrtc-8-0 cuda-nvrtc-dev-8-0
#   cuda-runtime-8-0 cuda-samples-8-0 cuda-toolkit-8-0 cuda-visual-tools-8-0 dctrl-tools default-jre
#   default-jre-headless dkms fakeroot fonts-dejavu-core fonts-dejavu-extra freeglut3 freeglut3-dev
#   gcc-12 keyboard-configuration libasan8 libatk-wrapper-java libatk-wrapper-java-jni libegl-dev
#   libfakeroot libfontenc1 libgcc-12-dev libgl-dev libgl1-mesa-dev libgles-dev libgles1 libglu1-mesa
#   libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libice-dev libjansson4
#   liblocale-gettext-perl libnvidia-cfg1-550 libnvidia-common-550 libnvidia-compute-550
#   libnvidia-decode-550 libnvidia-encode-550 libnvidia-extra-550 libnvidia-fbc1-550 libnvidia-gl-550
#   libopengl-dev libsm-dev libtsan2 libxcvt0 libxfixes-dev libxfont2 libxi-dev libxkbfile1
#   libxmu-dev libxmu-headers libxt-dev libxtst6 libxxf86dga1 nvidia-compute-utils-550
#   nvidia-dkms-550 nvidia-driver-550 nvidia-firmware-550-550.54.15 nvidia-kernel-common-550
#   nvidia-kernel-source-550 nvidia-prime nvidia-settings nvidia-utils-550 openjdk-11-jre
#   python3-xkit screen-resolution-extra systemd-hwe-hwdb udev x11-utils x11-xkb-utils xcvt
#   xfonts-base xfonts-encodings xfonts-utils xserver-common xserver-xorg-core
#   xserver-xorg-video-nvidia-550
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 109 newly installed, 0 to remove and 44 not upgraded.
# Need to get 325 MB/1,637 MB of archives.
# After this operation, 2,984 MB of additional disk space will be used.
# Get:1 file:/var/cuda-repo-8-0-local-ga2  cuda-license-8-0 8.0.61-1 [27.6 kB]
# Get:2 file:/var/cuda-repo-8-0-local-ga2  cuda-misc-headers-8-0 8.0.61-1 [1,077 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-common-550 550.54.15-0ubuntu1 [17.1 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-compute-550 550.54.15-0ubuntu1 [49.5 MB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblocale-gettext-perl amd64 1.07-4build3 [17.1 kB]
# Get:6 file:/var/cuda-repo-8-0-local-ga2  cuda-core-8-0 8.0.61-1 [20.0 MB]
# Get:7 file:/var/cuda-repo-8-0-local-ga2  cuda-cudart-8-0 8.0.61-1 [135 kB]
# Get:8 file:/var/cuda-repo-8-0-local-ga2  cuda-driver-dev-8-0 8.0.61-1 [14.1 kB]
# Get:9 file:/var/cuda-repo-8-0-local-ga2  cuda-cudart-dev-8-0 8.0.61-1 [1,071 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 keyboard-configuration all 1.205ubuntu3 [206 kB]
# Get:11 file:/var/cuda-repo-8-0-local-ga2  cuda-command-line-tools-8-0 8.0.61-1 [26.1 MB]
# Get:12 file:/var/cuda-repo-8-0-local-ga2  cuda-nvrtc-8-0 8.0.61-1 [9,585 kB]
# Get:13 file:/var/cuda-repo-8-0-local-ga2  cuda-nvrtc-dev-8-0 8.0.61-1 [10.8 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 cpp-12 amd64 12.3.0-1ubuntu1~22.04 [10.8 MB]
# Get:15 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-gl-550 550.54.15-0ubuntu1 [136 MB]
# Get:16 file:/var/cuda-repo-8-0-local-ga2  cuda-cusolver-8-0 8.0.61-1 [29.3 MB]
# Get:17 file:/var/cuda-repo-8-0-local-ga2  cuda-cusolver-dev-8-0 8.0.61-1 [6,816 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libasan8 amd64 12.3.0-1ubuntu1~22.04 [2,442 kB]
# Get:19 file:/var/cuda-repo-8-0-local-ga2  cuda-cublas-8-0 8.0.61-1 [27.2 MB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtsan2 amd64 12.3.0-1ubuntu1~22.04 [2,477 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgcc-12-dev amd64 12.3.0-1ubuntu1~22.04 [2,618 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gcc-12 amd64 12.3.0-1ubuntu1~22.04 [21.7 MB]
# Get:23 file:/var/cuda-repo-8-0-local-ga2  cuda-cublas-dev-8-0 8.0.61-1 [57.4 MB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 dctrl-tools amd64 2.24-3build2 [66.9 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dkms all 2.8.7-2ubuntu2.2 [70.1 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.12 [78.2 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.12 [1,557 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjansson4 amd64 2.13.1-1.1build3 [32.4 kB]
# Get:29 file:/var/cuda-repo-8-0-local-ga2  cuda-cufft-8-0 8.0.61-1 [117 MB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3 amd64 2.8.1-6 [74.0 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [6,842 B]
# Get:40 file:/var/cuda-repo-8-0-local-ga2  cuda-cufft-dev-8-0 8.0.61-1 [94.8 MB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:42 file:/var/cuda-repo-8-0-local-ga2  cuda-curand-8-0 8.0.61-1 [43.7 MB]
# Get:43 file:/var/cuda-repo-8-0-local-ga2  cuda-curand-dev-8-0 8.0.61-1 [67.7 MB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# Get:45 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-source-550 550.54.15-0ubuntu1 [41.1 MB]
# Get:46 file:/var/cuda-repo-8-0-local-ga2  cuda-cusparse-8-0 8.0.61-1 [28.8 MB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libice-dev amd64 2:1.0.10-1build2 [51.4 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsm-dev amd64 2:1.2.3-1build2 [18.1 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt-dev amd64 1:1.2.1-1 [396 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3-dev amd64 2.8.1-6 [126 kB]
# Get:51 file:/var/cuda-repo-8-0-local-ga2  cuda-cusparse-dev-8-0 8.0.61-1 [29.6 MB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmu-headers all 2:1.1.3-3 [54.1 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmu-dev amd64 2:1.1.3-3 [54.6 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfixes-dev amd64 1:6.0.0-1 [12.2 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxi-dev amd64 2:1.8-1build1 [193 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.22+7-0ubuntu2~22.04.1 [214 kB]
# Get:59 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-firmware-550-550.54.15 550.54.15-0ubuntu1 [36.8 MB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.9 [28.5 kB]
# Get:64 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-common-550 550.54.15-0ubuntu1 [109 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt0 amd64 0.1.1-3 [5,494 B]
# Get:66 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-dkms-550 550.54.15-0ubuntu1 [36.2 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:68 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-extra-550 550.54.15-0ubuntu1 [71.1 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-core amd64 2:21.1.4-2ubuntu1.7~22.04.9 [1,477 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfakeroot amd64 1.28-1ubuntu1 [31.5 kB]
# Get:72 file:/var/cuda-repo-8-0-local-ga2  cuda-npp-8-0 8.0.61-1 [157 MB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/main amd64 fakeroot amd64 1.28-1ubuntu1 [60.4 kB]
# Get:74 file:/var/cuda-repo-8-0-local-ga2  cuda-npp-dev-8-0 8.0.61-1 [82.3 MB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:77 file:/var/cuda-repo-8-0-local-ga2  cuda-samples-8-0 8.0.61-1 [101 MB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 nvidia-prime all 0.8.17.1 [9,956 B]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-xkit all 0.5.0ubuntu5 [18.5 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/main amd64 screen-resolution-extra all 0.18.2 [4,396 B]
# Get:85 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/main amd64 xcvt amd64 0.1.1-3 [7,140 B]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:88 file:/var/cuda-repo-8-0-local-ga2  cuda-documentation-8-0 8.0.61-1 [113 MB]
# Get:89 file:/var/cuda-repo-8-0-local-ga2  cuda-nvml-dev-8-0 8.0.61-1 [48.4 kB]
# Get:90 file:/var/cuda-repo-8-0-local-ga2  cuda-nvgraph-8-0 8.0.61-1 [2,948 kB]
# Get:91 file:/var/cuda-repo-8-0-local-ga2  cuda-nvgraph-dev-8-0 8.0.61-1 [3,028 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:94 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-compute-utils-550 550.54.15-0ubuntu1 [118 kB]
# Get:95 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-decode-550 550.54.15-0ubuntu1 [1,783 kB]
# Get:96 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-encode-550 550.54.15-0ubuntu1 [100 kB]
# Get:97 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-utils-550 550.54.15-0ubuntu1 [494 kB]
# Get:98 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-cfg1-550 550.54.15-0ubuntu1 [145 kB]
# Get:99 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  xserver-xorg-video-nvidia-550 550.54.15-0ubuntu1 [1,534 kB]
# Get:100 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-fbc1-550 550.54.15-0ubuntu1 [54.9 kB]
# Get:101 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-driver-550 550.54.15-0ubuntu1 [489 kB]
# Get:102 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-drivers-550 550.54.15-1 [2,542 B]
# Get:103 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-drivers 550.54.15-1 [2,502 B]
# Get:104 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-settings 550.54.15-0ubuntu1 [947 kB]
# Get:105 file:/var/cuda-repo-8-0-local-ga2  cuda-visual-tools-8-0 8.0.61-1 [286 MB]
# Get:106 file:/var/cuda-repo-8-0-local-ga2  cuda-toolkit-8-0 8.0.61-1 [2,892 B]
# Get:107 file:/var/cuda-repo-8-0-local-ga2  cuda-runtime-8-0 8.0.61-1 [2,574 B]
# Get:108 file:/var/cuda-repo-8-0-local-ga2  cuda-demo-suite-8-0 8.0.61-1 [4,988 kB]
# Get:109 file:/var/cuda-repo-8-0-local-ga2  cuda-8-0 8.0.61-1 [2,556 B]
# Get:110 file:/var/cuda-repo-8-0-local-ga2  cuda 8.0.61-1 [2,510 B]
# Fetched 325 MB in 15s (21.8 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 121847 files and directories currently installed.)
# Preparing to unpack .../0-liblocale-gettext-perl_1.07-4build3_amd64.deb ...
# Unpacking liblocale-gettext-perl (1.07-4build3) ...
# Selecting previously unselected package keyboard-configuration.
# Preparing to unpack .../1-keyboard-configuration_1.205ubuntu3_all.deb ...
# Unpacking keyboard-configuration (1.205ubuntu3) ...
# Selecting previously unselected package cpp-12.
# Preparing to unpack .../2-cpp-12_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking cpp-12 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libasan8:amd64.
# Preparing to unpack .../3-libasan8_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libasan8:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libtsan2:amd64.
# Preparing to unpack .../4-libtsan2_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libtsan2:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libgcc-12-dev:amd64.
# Preparing to unpack .../5-libgcc-12-dev_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libgcc-12-dev:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package gcc-12.
# Preparing to unpack .../6-gcc-12_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking gcc-12 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package dctrl-tools.
# Preparing to unpack .../7-dctrl-tools_2.24-3build2_amd64.deb ...
# Unpacking dctrl-tools (2.24-3build2) ...
# Selecting previously unselected package dkms.
# Preparing to unpack .../8-dkms_2.8.7-2ubuntu2.2_all.deb ...
# Unpacking dkms (2.8.7-2ubuntu2.2) ...
# Preparing to unpack .../9-libudev1_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.12) over (249.11-0ubuntu3.10) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.12) ...
# Selecting previously unselected package udev.
# (Reading database ... 122207 files and directories currently installed.)
# Preparing to unpack .../00-udev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.12) ...
# Selecting previously unselected package libjansson4:amd64.
# Preparing to unpack .../01-libjansson4_2.13.1-1.1build3_amd64.deb ...
# Unpacking libjansson4:amd64 (2.13.1-1.1build3) ...
# Selecting previously unselected package cuda-license-8-0.
# Preparing to unpack .../02-cuda-license-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-license-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-misc-headers-8-0.
# Preparing to unpack .../03-cuda-misc-headers-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-misc-headers-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-core-8-0.
# Preparing to unpack .../04-cuda-core-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-core-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cudart-8-0.
# Preparing to unpack .../05-cuda-cudart-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cudart-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-driver-dev-8-0.
# Preparing to unpack .../06-cuda-driver-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-driver-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cudart-dev-8-0.
# Preparing to unpack .../07-cuda-cudart-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cudart-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-command-line-tools-8-0.
# Preparing to unpack .../08-cuda-command-line-tools-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-command-line-tools-8-0 (8.0.61-1) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../09-freeglut3_2.8.1-6_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-6) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../10-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../11-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../12-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../13-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../14-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../15-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../16-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../17-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../18-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../19-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../20-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../21-libice-dev_2%3a1.0.10-1build2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-1build2) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../22-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../23-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../24-freeglut3-dev_2.8.1-6_amd64.deb ...
# Unpacking freeglut3-dev:amd64 (2.8.1-6) ...
# Selecting previously unselected package libxmu-headers.
# Preparing to unpack .../25-libxmu-headers_2%3a1.1.3-3_all.deb ...
# Unpacking libxmu-headers (2:1.1.3-3) ...
# Selecting previously unselected package libxmu-dev:amd64.
# Preparing to unpack .../26-libxmu-dev_2%3a1.1.3-3_amd64.deb ...
# Unpacking libxmu-dev:amd64 (2:1.1.3-3) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../27-libxfixes-dev_1%3a6.0.0-1_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:6.0.0-1) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../28-libxi-dev_2%3a1.8-1build1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.8-1build1) ...
# Selecting previously unselected package cuda-nvrtc-8-0.
# Preparing to unpack .../29-cuda-nvrtc-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvrtc-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-8-0.
# Preparing to unpack .../30-cuda-nvrtc-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusolver-8-0.
# Preparing to unpack .../31-cuda-cusolver-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusolver-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusolver-dev-8-0.
# Preparing to unpack .../32-cuda-cusolver-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusolver-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cublas-8-0.
# Preparing to unpack .../33-cuda-cublas-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cublas-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cublas-dev-8-0.
# Preparing to unpack .../34-cuda-cublas-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cublas-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cufft-8-0.
# Preparing to unpack .../35-cuda-cufft-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cufft-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cufft-dev-8-0.
# Preparing to unpack .../36-cuda-cufft-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cufft-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-curand-8-0.
# Preparing to unpack .../37-cuda-curand-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-curand-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-curand-dev-8-0.
# Preparing to unpack .../38-cuda-curand-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-curand-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusparse-8-0.
# Preparing to unpack .../39-cuda-cusparse-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusparse-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusparse-dev-8-0.
# Preparing to unpack .../40-cuda-cusparse-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusparse-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-npp-8-0.
# Preparing to unpack .../41-cuda-npp-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-npp-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-npp-dev-8-0.
# Preparing to unpack .../42-cuda-npp-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-npp-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-samples-8-0.
# Preparing to unpack .../43-cuda-samples-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-samples-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-documentation-8-0.
# Preparing to unpack .../44-cuda-documentation-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-documentation-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvml-dev-8-0.
# Preparing to unpack .../45-cuda-nvml-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvml-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvgraph-8-0.
# Preparing to unpack .../46-cuda-nvgraph-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvgraph-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvgraph-dev-8-0.
# Preparing to unpack .../47-cuda-nvgraph-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvgraph-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../48-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../49-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../50-openjdk-11-jre_11.0.22+7-0ubuntu2~22.04.1_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.22+7-0ubuntu2~22.04.1) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../51-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package cuda-visual-tools-8-0.
# Preparing to unpack .../52-cuda-visual-tools-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-visual-tools-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-toolkit-8-0.
# Preparing to unpack .../53-cuda-toolkit-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-toolkit-8-0 (8.0.61-1) ...
# Selecting previously unselected package libnvidia-common-550.
# Preparing to unpack .../54-libnvidia-common-550_550.54.15-0ubuntu1_all.deb ...
# Unpacking libnvidia-common-550 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-550:amd64.
# Preparing to unpack .../55-libnvidia-compute-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-550:amd64 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-gl-550:amd64.
# Preparing to unpack .../56-libnvidia-gl-550_550.54.15-0ubuntu1_amd64.deb ...
# dpkg-query: no packages found matching libnvidia-gl-535
# Unpacking libnvidia-gl-550:amd64 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-source-550.
# Preparing to unpack .../57-nvidia-kernel-source-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-source-550 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-firmware-550-550.54.15.
# Preparing to unpack .../58-nvidia-firmware-550-550.54.15_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-firmware-550-550.54.15 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-common-550.
# Preparing to unpack .../59-nvidia-kernel-common-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-common-550 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-dkms-550.
# Preparing to unpack .../60-nvidia-dkms-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-dkms-550 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-extra-550:amd64.
# Preparing to unpack .../61-libnvidia-extra-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-extra-550:amd64 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-compute-utils-550.
# Preparing to unpack .../62-nvidia-compute-utils-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-compute-utils-550 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-decode-550:amd64.
# Preparing to unpack .../63-libnvidia-decode-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-decode-550:amd64 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-encode-550:amd64.
# Preparing to unpack .../64-libnvidia-encode-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-encode-550:amd64 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-utils-550.
# Preparing to unpack .../65-nvidia-utils-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-utils-550 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-cfg1-550:amd64.
# Preparing to unpack .../66-libnvidia-cfg1-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-cfg1-550:amd64 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../67-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../68-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../69-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.9_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.9) ...
# Selecting previously unselected package libxcvt0:amd64.
# Preparing to unpack .../70-libxcvt0_0.1.1-3_amd64.deb ...
# Unpacking libxcvt0:amd64 (0.1.1-3) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../71-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../72-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package xserver-xorg-core.
# Preparing to unpack .../73-xserver-xorg-core_2%3a21.1.4-2ubuntu1.7~22.04.9_amd64.deb ...
# Unpacking xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.9) ...
# Selecting previously unselected package xserver-xorg-video-nvidia-550.
# Preparing to unpack .../74-xserver-xorg-video-nvidia-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-550 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-fbc1-550:amd64.
# Preparing to unpack .../75-libnvidia-fbc1-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-fbc1-550:amd64 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-driver-550.
# Preparing to unpack .../76-nvidia-driver-550_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-driver-550 (550.54.15-0ubuntu1) ...
# Selecting previously unselected package cuda-drivers-550.
# Preparing to unpack .../77-cuda-drivers-550_550.54.15-1_amd64.deb ...
# Unpacking cuda-drivers-550 (550.54.15-1) ...
# Selecting previously unselected package cuda-drivers.
# Preparing to unpack .../78-cuda-drivers_550.54.15-1_amd64.deb ...
# Unpacking cuda-drivers (550.54.15-1) ...
# Selecting previously unselected package cuda-runtime-8-0.
# Preparing to unpack .../79-cuda-runtime-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-runtime-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-demo-suite-8-0.
# Preparing to unpack .../80-cuda-demo-suite-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-demo-suite-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-8-0.
# Preparing to unpack .../81-cuda-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda.
# Preparing to unpack .../82-cuda_8.0.61-1_amd64.deb ...
# Unpacking cuda (8.0.61-1) ...
# Selecting previously unselected package libfakeroot:amd64.
# Preparing to unpack .../83-libfakeroot_1.28-1ubuntu1_amd64.deb ...
# Unpacking libfakeroot:amd64 (1.28-1ubuntu1) ...
# Selecting previously unselected package fakeroot.
# Preparing to unpack .../84-fakeroot_1.28-1ubuntu1_amd64.deb ...
# Unpacking fakeroot (1.28-1ubuntu1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../85-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../86-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../87-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../88-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../89-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../90-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package nvidia-prime.
# Preparing to unpack .../91-nvidia-prime_0.8.17.1_all.deb ...
# Unpacking nvidia-prime (0.8.17.1) ...
# Selecting previously unselected package python3-xkit.
# Preparing to unpack .../92-python3-xkit_0.5.0ubuntu5_all.deb ...
# Unpacking python3-xkit (0.5.0ubuntu5) ...
# Selecting previously unselected package screen-resolution-extra.
# Preparing to unpack .../93-screen-resolution-extra_0.18.2_all.deb ...
# Unpacking screen-resolution-extra (0.18.2) ...
# Selecting previously unselected package nvidia-settings.
# Preparing to unpack .../94-nvidia-settings_550.54.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (550.54.15-0ubuntu1) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../95-systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Selecting previously unselected package xcvt.
# Preparing to unpack .../96-xcvt_0.1.1-3_amd64.deb ...
# Unpacking xcvt (0.1.1-3) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../97-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../98-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../99-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Setting up libxmu-headers (2:1.1.3-3) ...
# Setting up cpp-12 (12.3.0-1ubuntu1~22.04) ...
# Setting up freeglut3:amd64 (2.8.1-6) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# Setting up libnvidia-compute-550:amd64 (550.54.15-0ubuntu1) ...
# Setting up nvidia-prime (0.8.17.1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libnvidia-common-550 (550.54.15-0ubuntu1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up nvidia-firmware-550-550.54.15 (550.54.15-0ubuntu1) ...
# Setting up nvidia-utils-550 (550.54.15-0ubuntu1) ...
# Setting up openjdk-11-jre:amd64 (11.0.22+7-0ubuntu2~22.04.1) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up libnvidia-fbc1-550:amd64 (550.54.15-0ubuntu1) ...
# Setting up libnvidia-cfg1-550:amd64 (550.54.15-0ubuntu1) ...
# Setting up nvidia-compute-utils-550 (550.54.15-0ubuntu1) ...
# Warning: The home dir /nonexistent you specified can't be accessed: No such file or directory
# Adding system user `nvidia-persistenced' (UID 104) ...
# Adding new group `nvidia-persistenced' (GID 107) ...
# Adding new user `nvidia-persistenced' (UID 104) with group `nvidia-persistenced' ...
# Not creating home directory `/nonexistent'.
# Setting up libfakeroot:amd64 (1.28-1ubuntu1) ...
# Setting up libjansson4:amd64 (2.13.1-1.1build3) ...
# Setting up fakeroot (1.28-1ubuntu1) ...
# update-alternatives: using /usr/bin/fakeroot-sysv to provide /usr/bin/fakeroot (fakeroot) in auto mode
# Setting up libxfixes-dev:amd64 (1:6.0.0-1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up udev (249.11-0ubuntu3.12) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Setting up libnvidia-gl-550:amd64 (550.54.15-0ubuntu1) ...
# Setting up nvidia-kernel-common-550 (550.54.15-0ubuntu1) ...
# Created symlink /etc/systemd/system/systemd-hibernate.service.wants/nvidia-hibernate.service → /lib/systemd/system/nvidia-hibernate.service.
# Created symlink /etc/systemd/system/systemd-suspend.service.wants/nvidia-resume.service → /lib/systemd/system/nvidia-resume.service.
# Created symlink /etc/systemd/system/systemd-hibernate.service.wants/nvidia-resume.service → /lib/systemd/system/nvidia-resume.service.
# Created symlink /etc/systemd/system/systemd-suspend.service.wants/nvidia-suspend.service → /lib/systemd/system/nvidia-suspend.service.
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libnvidia-extra-550:amd64 (550.54.15-0ubuntu1) ...
# Setting up libasan8:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up libxcvt0:amd64 (0.1.1-3) ...
# Setting up nvidia-kernel-source-550 (550.54.15-0ubuntu1) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libtsan2:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up libxi-dev:amd64 (2:1.8-1build1) ...
# Setting up python3-xkit (0.5.0ubuntu5) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up liblocale-gettext-perl (1.07-4build3) ...
# Setting up dctrl-tools (2.24-3build2) ...
# Setting up cuda-license-8-0 (8.0.61-1) ...
# *** LICENSE AGREEMENT ***
# By using this software you agree to fully comply with the terms and
# conditions of the EULA (End User License Agreement). The EULA is located
# at /usr/local/cuda-8.0/doc/EULA.txt. The EULA can also be found at
# http://docs.nvidia.com/cuda/eula/index.html. If you do not agree to the
# terms and conditions of the EULA, do not use the software.
#
# Setting up cuda-cudart-8-0 (8.0.61-1) ...
# Setting up cuda-cublas-8-0 (8.0.61-1) ...
# Setting up libnvidia-decode-550:amd64 (550.54.15-0ubuntu1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up cuda-curand-8-0 (8.0.61-1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up cuda-nvgraph-8-0 (8.0.61-1) ...
# Setting up libxmu-dev:amd64 (2:1.1.3-3) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libnvidia-encode-550:amd64 (550.54.15-0ubuntu1) ...
# Setting up cuda-nvrtc-8-0 (8.0.61-1) ...
# Setting up xcvt (0.1.1-3) ...
# Setting up cuda-cusparse-8-0 (8.0.61-1) ...
# Setting up cuda-curand-dev-8-0 (8.0.61-1) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up cuda-cufft-8-0 (8.0.61-1) ...
# Setting up cuda-nvgraph-dev-8-0 (8.0.61-1) ...
# Setting up libgcc-12-dev:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-nvml-dev-8-0 (8.0.61-1) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up cuda-driver-dev-8-0 (8.0.61-1) ...
# Setting up screen-resolution-extra (0.18.2) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up cuda-cublas-dev-8-0 (8.0.61-1) ...
# Setting up nvidia-settings (550.54.15-0ubuntu1) ...
# Setting up cuda-cusolver-8-0 (8.0.61-1) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.9) ...
# Setting up keyboard-configuration (1.205ubuntu3) ...
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up cuda-npp-8-0 (8.0.61-1) ...
# Setting up cuda-cusolver-dev-8-0 (8.0.61-1) ...
# Setting up cuda-misc-headers-8-0 (8.0.61-1) ...
# Setting up cuda-nvrtc-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cusparse-dev-8-0 (8.0.61-1) ...
# Setting up cuda-core-8-0 (8.0.61-1) ...
# Setting up cuda-cudart-dev-8-0 (8.0.61-1) ...
# Setting up xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.9) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up cuda-npp-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cufft-dev-8-0 (8.0.61-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up gcc-12 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-command-line-tools-8-0 (8.0.61-1) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up xserver-xorg-video-nvidia-550 (550.54.15-0ubuntu1) ...
# Setting up dkms (2.8.7-2ubuntu2.2) ...
# Setting up freeglut3-dev:amd64 (2.8.1-6) ...
# Setting up cuda-visual-tools-8-0 (8.0.61-1) ...
# Setting up cuda-samples-8-0 (8.0.61-1) ...
# Setting up nvidia-dkms-550 (550.54.15-0ubuntu1) ...
# Loading new nvidia-550.54.15 DKMS files...
# It is likely that 6.1.58+ belongs to a chroot's host
# Building for 5.15.0-101-generic
# Building for architecture x86_64
# Building initial module for 5.15.0-101-generic
# Done.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-101-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-101-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-101-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-101-generic/updates/dkms/
#
# nvidia-peermem.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-101-generic/updates/dkms/
#
# depmod...
# Setting up cuda-documentation-8-0 (8.0.61-1) ...
# Setting up cuda-toolkit-8-0 (8.0.61-1) ...
# Setting up nvidia-driver-550 (550.54.15-0ubuntu1) ...
# Setting up cuda-drivers-550 (550.54.15-1) ...
# Setting up cuda-drivers (550.54.15-1) ...
# Setting up cuda-runtime-8-0 (8.0.61-1) ...
# Setting up cuda-demo-suite-8-0 (8.0.61-1) ...
# Setting up cuda-8-0 (8.0.61-1) ...
# Setting up cuda (8.0.61-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# --2024-04-05 15:32:04--  http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64/libcudnn6_6.0.21-1%2Bcuda8.0_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68497194 (65M) [application/x-deb]
# Saving to: ‘libcudnn6_6.0.21-1+cuda8.0_amd64.deb’
#
# libcudnn6_6.0.21-1+ 100%[===================>]  65.32M  19.4MB/s    in 3.7s
#
# 2024-04-05 15:32:09 (17.7 MB/s) - ‘libcudnn6_6.0.21-1+cuda8.0_amd64.deb’ saved [68497194/68497194]
#
# --2024-04-05 15:32:09--  http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64/libcudnn6-dev_6.0.21-1%2Bcuda8.0_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59876426 (57M) [application/x-deb]
# Saving to: ‘libcudnn6-dev_6.0.21-1+cuda8.0_amd64.deb’
#
# libcudnn6-dev_6.0.2 100%[===================>]  57.10M  16.1MB/s    in 3.6s
#
# 2024-04-05 15:32:12 (16.1 MB/s) - ‘libcudnn6-dev_6.0.21-1+cuda8.0_amd64.deb’ saved [59876426/59876426]
#
# Selecting previously unselected package libcudnn6.
# (Reading database ... 133505 files and directories currently installed.)
# Preparing to unpack libcudnn6_6.0.21-1+cuda8.0_amd64.deb ...
# Unpacking libcudnn6 (6.0.21-1+cuda8.0) ...
# Setting up libcudnn6 (6.0.21-1+cuda8.0) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# Selecting previously unselected package libcudnn6-dev.
# (Reading database ... 133511 files and directories currently installed.)
# Preparing to unpack libcudnn6-dev_6.0.21-1+cuda8.0_amd64.deb ...
# Unpacking libcudnn6-dev (6.0.21-1+cuda8.0) ...
# Setting up libcudnn6-dev (6.0.21-1+cuda8.0) ...
# update-alternatives: using /usr/include/x86_64-linux-gnu/cudnn_v6.h to provide /usr/include/cudnn.h (libcudnn) in manual mode
# Get:1 file:/var/cuda-repo-8-0-local-ga2  InRelease
# Ign:1 file:/var/cuda-repo-8-0-local-ga2  InRelease
# Get:2 file:/var/cuda-repo-8-0-local-ga2  Release [574 B]
# Get:2 file:/var/cuda-repo-8-0-local-ga2  Release [574 B]
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 110 kB in 1s (78.1 kB/s)
# Reading package lists... Done
# W: file:/var/cuda-repo-8-0-local-ga2/Release.gpg: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libcudnn6-dev is already the newest version (6.0.21-1+cuda8.0).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# Clone the official github repo here
# !git clone https://github.com/t0rn/deep_motion_mag.git
# Out:
# Cloning into 'deep_motion_mag'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 34 (delta 5), reused 4 (delta 4), pack-reused 20
# Receiving objects: 100% (34/34), 21.26 KiB | 10.63 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# Go into the  corresponding folder
# %cd deep_motion_mag
# Out:
# /content/deep_motion_mag

# %%
# Install all the requirements
# !pip install -r requirements.txt
# !ls
# Warning::
# Since this repository works on all the older versions of library after this step you might need to consider restarting the runtime for proper installation.
# if you restart runtime your all the above updates would be lost so please run once all cells from cell number 3 otherwise you'll stuck in error.
# Out:
# Collecting configobj==5.0.8 (from -r requirements.txt (line 9))
#   Using cached configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy==1.25.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 10)) (1.25.2)
# Requirement already satisfied: opencv-python==4.8.0.76 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 11)) (4.8.0.76)
# Requirement already satisfied: scipy==1.11.4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 12)) (1.11.4)
# Collecting setproctitle==1.1.10 (from -r requirements.txt (line 13))
#   Using cached setproctitle-1.1.10.zip (34 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 14)) (2.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 15)) (4.66.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from configobj==5.0.8->-r requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (1.62.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->-r requirements.txt (line 14)) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 14)) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->-r requirements.txt (line 14)) (3.2.2)
# Building wheels for collected packages: setproctitle
#   Building wheel for setproctitle (setup.py) ... done
#   Created wheel for setproctitle: filename=setproctitle-1.1.10-cp310-cp310-linux_x86_64.whl size=28483 sha256=5d982745200b1fd0a2e814e55632b95aec4046c316e9ad7d8527328dc7472ce6
#   Stored in directory: /root/.cache/pip/wheels/fa/aa/00/7ea7ba40a9fe3eb817f820bc1c3e4eb66445d5614800de9898
# Successfully built setproctitle
# Installing collected packages: setproctitle, configobj
# Successfully installed configobj-5.0.8 setproctitle-1.1.10
# configs				      main.py	       requirements.txt
# convert_3frames_data_to_tfrecords.py  modules.py       run_on_test_videos.sh
# data_loader.py			      ops.py	       run_temporal_on_test_videos.sh
# LICENSE				      preprocessor.py  train.sh
# magnet.py			      README.md        utils.py

# %%
# Download the pretrained model into the folder after confirming that you are in the repo's folder.
# !wget https://people.csail.mit.edu/tiam/deepmag/data.zip

# Unzip the Folder
# !unzip data.zip

# Delete the zip.
# !rm -r data.zip
# Out:
# --2024-04-05 15:57:09--  https://people.csail.mit.edu/tiam/deepmag/data.zip
# Resolving people.csail.mit.edu (people.csail.mit.edu)... 128.30.2.133
# Connecting to people.csail.mit.edu (people.csail.mit.edu)|128.30.2.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6863956 (6.5M) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>]   6.55M  3.15MB/s    in 2.1s
#
# 2024-04-05 15:57:12 (3.15 MB/s) - ‘data.zip’ saved [6863956/6863956]
#
# Archive:  data.zip
#    creating: data/
#    creating: data/output/
#   inflating: data/output/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/data/
#    creating: __MACOSX/data/output/
#   inflating: __MACOSX/data/output/._.DS_Store
#    creating: data/training/
#    creating: data/training/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3/
#   inflating: data/training/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3/.DS_Store
#    creating: __MACOSX/data/training/
#    creating: __MACOSX/data/training/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3/
#   inflating: __MACOSX/data/training/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3/._.DS_Store
#    creating: data/training/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3/checkpoint/
#   inflating: data/training/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3/checkpoint/checkpoint
#   inflating: data/training/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3/checkpoint/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3-259002.data-00000-of-00001
#   inflating: data/training/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3/checkpoint/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3-259002.index
#   inflating: data/training/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3/checkpoint/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3-259002.meta
#    creating: data/vids/
#   inflating: data/vids/.DS_Store
#    creating: __MACOSX/data/vids/
#   inflating: __MACOSX/data/vids/._.DS_Store

# %%
# For testing purpose you have to follow link on the github repo, we are using the same baby video to show the working.
# !wget https://people.csail.mit.edu/mrub/evm/video/baby.mp4

# We have to extract the frames to the corresponding folder.
# 1. Create the corresponding folder (Last 'baby' should be replaced by your video name)
# !mkdir /content/deep_motion_mag/data/vids/baby

# 2. Extract the frames to that corresponding folder. ('ffmpeg -i source -f image2 destination')
# !ffmpeg -i /content/deep_motion_mag/baby.mp4 -f image2 /content/deep_motion_mag/data/vids/baby/%06d.png
# Out:
# --2024-04-05 15:57:23--  https://people.csail.mit.edu/mrub/evm/video/baby.mp4
# Resolving people.csail.mit.edu (people.csail.mit.edu)... 128.30.2.133
# Connecting to people.csail.mit.edu (people.csail.mit.edu)|128.30.2.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1839450 (1.8M) [video/mp4]
# Saving to: ‘baby.mp4’
#
# baby.mp4            100%[===================>]   1.75M  1.11MB/s    in 1.6s
#
# 2024-04-05 15:57:25 (1.11 MB/s) - ‘baby.mp4’ saved [1839450/1839450]
#
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/deep_motion_mag/baby.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42isomavc1
#     creation_time   : 2012-06-12T18:58:23.000000Z
#     encoder         : HandBrake 0.9.6 2012022800
#   Duration: 00:00:10.03, start: 0.000000, bitrate: 1466 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/smpte170m/bt709), 960x544, 1462 kb/s, 30 fps, 30 tbr, 90k tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2012-06-12T18:58:23.000000Z
#       vendor_id       : [0][0][0][0]
#       encoder         : JVT/AVC Coding
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/content/deep_motion_mag/data/vids/baby/%06d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42isomavc1
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/smpte170m/bt709, progressive), 960x544, q=2-31, 200 kb/s, 30 fps, 30 tbn (default)
#     Metadata:
#       creation_time   : 2012-06-12T18:58:23.000000Z
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 png
# frame=  301 fps= 21 q=-0.0 Lsize=N/A time=00:00:10.03 bitrate=N/A speed=0.701x
# video:178610kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# To run the test script we are using the dynamic mode you can use any mode that is specified by the author.
# !sh run_on_test_videos.sh o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3 baby 10 yes
# Out:
# 2024-04-05 15:59:56.172559: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-05 15:59:56.172609: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-05 15:59:56.292125: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-05 15:59:56.505732: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-05 15:59:58.059224: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-05 16:00:00.907638: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-05 16:00:01.403883: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-05 16:00:01.404250: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-05 16:00:01.543166: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-05 16:00:01.543523: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-05 16:00:01.543756: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-05 16:00:01.543922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1697: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: resize_nearest_neighbor (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.image.resize(...method=ResizeMethod.NEAREST_NEIGHBOR...)` instead.
# 2024-04-05 16:00:02.272866: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
#  [*] Reading checkpoint...
# Loaded from ckpt: data/training/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3/checkpoint/o3f_hmhm2_bg_qnoise_mix4_nl_n_t_ds3-259002
# [*] Load Success
# Iteration number is 259002
# Running in Dynamic mode
# baby_25900:   0% 0/301 [00:00<?, ?it/s]2024-04-05 16:00:03.091854: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 2024-04-05 16:00:03.702710: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:03.705228: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:225] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 7.5
# 2024-04-05 16:00:03.705266: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:228] Used ptxas at ptxas
# 2024-04-05 16:00:03.705370: W external/local_xla/xla/stream_executor/gpu/redzone_allocator.cc:322] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-04-05 16:00:04.710458: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:04.711224: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:04.715698: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:04.720429: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:06.825882: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:06.827272: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:06.828685: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:06.829954: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:06.834755: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:06.837070: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:06.840428: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:06.842639: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:06.842777: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:06.844861: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:06.849092: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:06.851171: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:06.852398: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:06.854510: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:06.857876: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:06.859372: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:07.204308: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:07.205077: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:07.207002: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:07.207320: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:07.212643: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:07.214991: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:07.219283: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:07.220938: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:07.221511: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:07.223188: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:07.228280: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:07.230421: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:07.230796: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:07.233038: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2024-04-05 16:00:07.237155: E external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 8.0.61, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2024-04-05 16:00:07.238702: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:191] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# baby_25900:  27% 82/301 [00:22<00:47,  4.63it/s]

# %%
# The output video will be under the path /data/output/(folder name)/file name (folder name is baby in our case and file name is baby_259002.mp4 )
# Navigating to the output Video to see the output
# !cd /content/deep_motion_mag/data/output/baby
# Out:
# /content/deep_motion_mag/data/output/baby

# %%
# Confirming that we are in the right folder and seeing the file name
# !ls
# Out:
# 000001.png  000039.png	000077.png  000115.png	000153.png  000191.png	000229.png  000267.png
# 000002.png  000040.png	000078.png  000116.png	000154.png  000192.png	000230.png  000268.png
# 000003.png  000041.png	000079.png  000117.png	000155.png  000193.png	000231.png  000269.png
# 000004.png  000042.png	000080.png  000118.png	000156.png  000194.png	000232.png  000270.png
# 000005.png  000043.png	000081.png  000119.png	000157.png  000195.png	000233.png  000271.png
# 000006.png  000044.png	000082.png  000120.png	000158.png  000196.png	000234.png  000272.png
# 000007.png  000045.png	000083.png  000121.png	000159.png  000197.png	000235.png  000273.png
# 000008.png  000046.png	000084.png  000122.png	000160.png  000198.png	000236.png  000274.png
# 000009.png  000047.png	000085.png  000123.png	000161.png  000199.png	000237.png  000275.png
# 000010.png  000048.png	000086.png  000124.png	000162.png  000200.png	000238.png  000276.png
# 000011.png  000049.png	000087.png  000125.png	000163.png  000201.png	000239.png  000277.png
# 000012.png  000050.png	000088.png  000126.png	000164.png  000202.png	000240.png  000278.png
# 000013.png  000051.png	000089.png  000127.png	000165.png  000203.png	000241.png  000279.png
# 000014.png  000052.png	000090.png  000128.png	000166.png  000204.png	000242.png  000280.png
# 000015.png  000053.png	000091.png  000129.png	000167.png  000205.png	000243.png  000281.png
# 000016.png  000054.png	000092.png  000130.png	000168.png  000206.png	000244.png  000282.png
# 000017.png  000055.png	000093.png  000131.png	000169.png  000207.png	000245.png  000283.png
# 000018.png  000056.png	000094.png  000132.png	000170.png  000208.png	000246.png  000284.png
# 000019.png  000057.png	000095.png  000133.png	000171.png  000209.png	000247.png  000285.png
# 000020.png  000058.png	000096.png  000134.png	000172.png  000210.png	000248.png  000286.png
# 000021.png  000059.png	000097.png  000135.png	000173.png  000211.png	000249.png  000287.png
# 000022.png  000060.png	000098.png  000136.png	000174.png  000212.png	000250.png  000288.png
# 000023.png  000061.png	000099.png  000137.png	000175.png  000213.png	000251.png  000289.png
# 000024.png  000062.png	000100.png  000138.png	000176.png  000214.png	000252.png  000290.png
# 000025.png  000063.png	000101.png  000139.png	000177.png  000215.png	000253.png  000291.png
# 000026.png  000064.png	000102.png  000140.png	000178.png  000216.png	000254.png  000292.png
# 000027.png  000065.png	000103.png  000141.png	000179.png  000217.png	000255.png  000293.png
# 000028.png  000066.png	000104.png  000142.png	000180.png  000218.png	000256.png  000294.png
# 000029.png  000067.png	000105.png  000143.png	000181.png  000219.png	000257.png  000295.png
# 000030.png  000068.png	000106.png  000144.png	000182.png  000220.png	000258.png  000296.png
# 000031.png  000069.png	000107.png  000145.png	000183.png  000221.png	000259.png  000297.png
# 000032.png  000070.png	000108.png  000146.png	000184.png  000222.png	000260.png  000298.png
# 000033.png  000071.png	000109.png  000147.png	000185.png  000223.png	000261.png  000299.png
# 000034.png  000072.png	000110.png  000148.png	000186.png  000224.png	000262.png  000300.png
# 000035.png  000073.png	000111.png  000149.png	000187.png  000225.png	000263.png  000301.png
# 000036.png  000074.png	000112.png  000150.png	000188.png  000226.png	000264.png  baby_259002.mp4
# 000037.png  000075.png	000113.png  000151.png	000189.png  000227.png	000265.png
# 000038.png  000076.png	000114.png  000152.png	000190.png  000228.png	000266.png

# %%
# Copy the video file to the drive so that you can manipulate them (View, Download, Share)!
# Below command assumes that you have a folder named magnified_videos in drive, if you want to save to other location then change the destination folder.
# %cp /content/deep_motion_mag/data/output/baby/baby_259002.mp4 /content/drive/My\ Drive/magnified_videos/

# Now you are done you can see your videos, into the destined folder.
# Out:
# cp: cannot create regular file '/content/drive/My Drive/magnified_videos/': Not a directory
